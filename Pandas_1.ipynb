# %%
import pandas as pd ##pandas always works with structured datas as same as SQL

# %%
df=pd.read_csv("student_dataset.csv")

# %%
pd.read_csv("student_dataset.csv",header=None)
# Out:
#           0            1      2                         3                   4  \
# 0    gender  raisedhands  score  ParentschoolSatisfaction  StudentAbsenceDays
# 1         M           15     20                      Good             Under-7
# 2         M           20     25                      Good             Under-7
# 3         M           10     30                       Bad             Above-7
# 4         M           30     35                       Bad             Above-7
# ..      ...          ...    ...                       ...                 ...
# 476       F            5      8                       Bad             Above-7
# 477       F           50     28                       Bad             Under-7
# 478       F           55     29                       Bad             Under-7
# 479       F           30     57                       Bad             Above-7
# 480       F           35     62                       Bad             Above-7
#
#          5
# 0    Class
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['gender', 'raisedhands', 'score', 'ParentschoolSatisfaction',
#        'StudentAbsenceDays', 'Class'],
#       dtype='object')

# %%
list(df.columns)
# Out:
# ['gender',
#  'raisedhands',
#  'score',
#  'ParentschoolSatisfaction',
#  'StudentAbsenceDays',
#  'Class']

# %%
df.head(5)##getting only 1st 5 records from the entire data set
# Out:
#   gender  raisedhands  score ParentschoolSatisfaction StudentAbsenceDays Class
# 0      M           15     20                     Good            Under-7     M
# 1      M           20     25                     Good            Under-7     M
# 2      M           10     30                      Bad            Above-7     L
# 3      M           30     35                      Bad            Above-7     L
# 4      M           40     50                      Bad            Above-7     M

# %%
df.tail() ## last 5 records by default 5 recods are printed
# Out:
#     gender  raisedhands  score ParentschoolSatisfaction StudentAbsenceDays  \
# 475      F            5      8                      Bad            Above-7
# 476      F           50     28                      Bad            Under-7
# 477      F           55     29                      Bad            Under-7
# 478      F           30     57                      Bad            Above-7
# 479      F           35     62                      Bad            Above-7
#
#     Class
# 475     L
# 476     M
# 477     M
# 478     L
# 479     L

# %%
df.dtypes ##coloumn data types
# Out:
# gender                      object
# raisedhands                  int64
# score                        int64
# ParentschoolSatisfaction    object
# StudentAbsenceDays          object
# Class                       object
# dtype: object

# %%
df.columns
# Out:
# Index(['gender', 'raisedhands', 'score', 'ParentschoolSatisfaction',
#        'StudentAbsenceDays', 'Class'],
#       dtype='object')

# %%
df["gender"] ##selecting a column
# Out:
# 0      M
# 1      M
# 2      M
# 3      M
# 4      M
#       ..
# 475    F
# 476    F
# 477    F
# 478    F
# 479    F
# Name: gender, Length: 480, dtype: object

# %%
type(df["gender"])##selecting a single record so type is series
# Out:
# pandas.core.series.Series

# %%
list(df["gender"])
# Out:
# ['M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'M',
#  'M',
#  'F',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'F',
#  'M',
#  'M',
#  'F',
#  'M',
#  'F',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'F',
#  'M',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'M',
#  'F',
#  'F',
#  'M',
#  'M',
#  'F',
#  'F',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'M',
#  'M',
#  'M',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'F',
#  'F',
#  'M',
#  'M',
#  'F',
#  'F',
#  'M',
#  'M',
#  'M',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'M',
#  'F',
#  'F',
#  'M',
# ...

# %%
df[["gender"]]
# Out:
#     gender
# 0        M
# 1        M
# 2        M
# 3        M
# 4        M
# ..     ...
# 475      F
# 476      F
# 477      F
# 478      F
# 479      F
#
# [480 rows x 1 columns]

# %%
type(df[["gender"]])##passing as a list so dataframe
# Out:
# pandas.core.frame.DataFrame

# %%
df["raisedhands", "score"]## to selects 2 columns togetger then pass it in a list
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('raisedhands', 'score')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df[["raisedhands", "score"]]## for multiple columns, pass in a list
# Out:
#      raisedhands  score
# 0             15     20
# 1             20     25
# 2             10     30
# 3             30     35
# 4             40     50
# ..           ...    ...
# 475            5      8
# 476           50     28
# 477           55     29
# 478           30     57
# 479           35     62
#
# [480 rows x 2 columns]

# %%
df_1=pd.read_excel("IMDB MOVIES RATING.xlsx")

# %%
df_1
# Out:
#      Movie Rank                 MovieName  Year Of Rekease  IMDB Rating
# 0             1  The Shawshank Redemption             1994          9.2
# 1             2             The Godfather             1972          9.2
# 2             3           The Dark Knight             2008          9.0
# 3             4     The Godfather Part II             1974          9.0
# 4             5              12 Angry Men             1957          9.0
# ..          ...                       ...              ...          ...
# 245         246               Dersu Uzala             1975          8.0
# 246         247                  The Help             2011          8.0
# 247         248                   Aladdin             1992          8.0
# 248         249                    Gandhi             1982          8.0
# 249         250        Dances with Wolves             1990          8.0
#
# [250 rows x 4 columns]

# %%
df.head(10)
# Out:
#   gender  raisedhands  score ParentschoolSatisfaction StudentAbsenceDays Class
# 0      M           15     20                     Good            Under-7     M
# 1      M           20     25                     Good            Under-7     M
# 2      M           10     30                      Bad            Above-7     L
# 3      M           30     35                      Bad            Above-7     L
# 4      M           40     50                      Bad            Above-7     M
# 5      F           42     70                      Bad            Above-7     M
# 6      M           35     17                      Bad            Above-7     L
# 7      M           50     22                     Good            Under-7     M
# 8      F           12     50                     Good            Under-7     M
# 9      F           70     70                     Good            Under-7     M

# %%
df.tail(10)
# Out:
#     gender  raisedhands  score ParentschoolSatisfaction StudentAbsenceDays  \
# 470      M           81     41                     Good            Under-7
# 471      M           78     53                     Good            Under-7
# 472      M           80     68                     Good            Under-7
# 473      M           85     70                     Good            Under-7
# 474      F            2      8                      Bad            Above-7
# 475      F            5      8                      Bad            Above-7
# 476      F           50     28                      Bad            Under-7
# 477      F           55     29                      Bad            Under-7
# 478      F           30     57                      Bad            Above-7
# 479      F           35     62                      Bad            Above-7
#
#     Class
# 470     M
# 471     M
# 472     M
# 473     M
# 474     L
# 475     L
# 476     M
# 477     M
# 478     L
# 479     L

# %%
type(df_1)
# Out:
# pandas.core.frame.DataFrame

# %%
df_1.dtypes##gives type of the column attributes
# Out:
# Movie Rank           int64
# MovieName           object
# Year Of Rekease      int64
# IMDB Rating        float64
# dtype: object

# %%
df_1.columns
# Out:
# Index(['Movie Rank', 'MovieName', 'Year Of Rekease', 'IMDB Rating'], dtype='object')

# %%
df_1["Movie Rank"]
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 245    246
# 246    247
# 247    248
# 248    249
# 249    250
# Name: Movie Rank, Length: 250, dtype: int64

# %%
df_1[["Movie Rank", "MovieName","IMDB Rating" ]]
# Out:
#      Movie Rank                 MovieName  IMDB Rating
# 0             1  The Shawshank Redemption          9.2
# 1             2             The Godfather          9.2
# 2             3           The Dark Knight          9.0
# 3             4     The Godfather Part II          9.0
# 4             5              12 Angry Men          9.0
# ..          ...                       ...          ...
# 245         246               Dersu Uzala          8.0
# 246         247                  The Help          8.0
# 247         248                   Aladdin          8.0
# 248         249                    Gandhi          8.0
# 249         250        Dances with Wolves          8.0
#
# [250 rows x 3 columns]

# %%
df_2=pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df_2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
type(df_2)
# Out:
# pandas.core.frame.DataFrame

# %%
df_2.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df_2.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df_2.tail(4)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df_2.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df_2["PassengerId"]
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 886    887
# 887    888
# 888    889
# 889    890
# 890    891
# Name: PassengerId, Length: 891, dtype: int64

# %%
type(df_2["PassengerId"])
# Out:
# pandas.core.series.Series

# %%
df_2[["PassengerId","Survived", "Pclass"]]
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
# [891 rows x 3 columns]

# %%
type(df_2[["PassengerId","Survived", "Pclass"]])
# Out:
# pandas.core.frame.DataFrame

# %%
df_2.to_csv("titanic_data.csv")##saving the data so u dont have to access again and again from url

# %%
df_2.to_csv("titanic_data.csv", index= False)

# %%
##load tabular data from a web page

# %%
## deta referance link "https://www.basketball-reference.com/leagues/NBA_2015_totals.html"

# %%
import lxml
url_data= pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_totals.html")

# %%
pd_3 ## only tabular tada
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
type(url_data) ## since data is in html form so there may be many tables so it gives in form of list
# Out:
# list

# %%
len(url_data)
# Out:
# 1

# %%
df_4=url_data[0]

# %%
df_4
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
df.head(4)
# Out:
#   gender  raisedhands  score ParentschoolSatisfaction StudentAbsenceDays Class
# 0      M           15     20                     Good            Under-7     M
# 1      M           20     25                     Good            Under-7     M
# 2      M           10     30                      Bad            Above-7     L
# 3      M           30     35                      Bad            Above-7     L

# %%
df.tail(6)
# Out:
#     gender  raisedhands  score ParentschoolSatisfaction StudentAbsenceDays  \
# 474      F            2      8                      Bad            Above-7
# 475      F            5      8                      Bad            Above-7
# 476      F           50     28                      Bad            Under-7
# 477      F           55     29                      Bad            Under-7
# 478      F           30     57                      Bad            Above-7
# 479      F           35     62                      Bad            Above-7
#
#     Class
# 474     L
# 475     L
# 476     M
# 477     M
# 478     L
# 479     L

# %%
df_4.dtypes
# Out:
# Rk        object
# Player    object
# Pos       object
# Age       object
# Tm        object
# G         object
# GS        object
# MP        object
# FG        object
# FGA       object
# FG%       object
# 3P        object
# 3PA       object
# 3P%       object
# 2P        object
# 2PA       object
# 2P%       object
# eFG%      object
# FT        object
# FTA       object
# FT%       object
# ORB       object
# DRB       object
# TRB       object
# AST       object
# STL       object
# BLK       object
# TOV       object
# PF        object
# PTS       object
# dtype: object

# %%
df_4.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
df_4["Rk"]
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 670    490
# 671    490
# 672    490
# 673    491
# 674    492
# Name: Rk, Length: 675, dtype: object

# %%
df_4[["Rk","TRB"]]
# Out:
#       Rk  TRB
# 0      1  301
# 1      2   28
# 2      3  523
# 3      4   77
# 4      5  247
# ..   ...  ...
# 670  490  411
# 671  490  245
# 672  490  166
# 673  491  362
# 674  492  465
#
# [675 rows x 2 columns]

# %%
df_4.to_csv("players.csv", index= False)

# %%
import pandas as pd

data = {'Name': ['John', 'Jane', 'Jim', 'Joan'],

        'Age': [25, 30, 35, 40],

        'Occupation': ['Engineer', 'Doctor', 'Teacher', 'Lawyer']}

df = pd.DataFrame(data)

print(df.loc[0])
# Out:
# Name              John
# Age                 25
# Occupation    Engineer
# Name: 0, dtype: object
